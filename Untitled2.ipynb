# %%
import os
import csv
import numpy as np
import pandas as pd
import re

working_dir = r"C:\Users\r-kajihara\Documents\Python\Versatilel_VirEnv\test"
file_name01 = "01.brs"
file_name02 = "02.brs"
file01 = os.path.join(working_dir, file_name01)
file02 = os.path.join(working_dir, file_name02)

with open(file01, "r", encoding="SHIFT-JIS") as file_data:
    r11 = file_data.read()
with open(file01, "r", encoding="SHIFT-JIS") as file_data:
    r12 = file_data.readlines()
with open(file02, "r", encoding="SHIFT-JIS") as file_data:
    r21 = file_data.read()
with open(file02, "r", encoding="SHIFT-JIS") as file_data:
    r22 = file_data.readlines()

# %%
r11[:20],r12[:5]
# Out:
# ('"BAS-3.4"\n"梨保存試験（R07',
#  ['"BAS-3.4"\n', '"梨保存試験（R071029）"\n', '"生（速度1mm）00"\n', '67\n', '67\n'])

# %%
r21[:20],r22[170:180]
# Out:
# ('"BAS-3.4"\n"梨保存試験（R07',
#  ['"Spare17"\n',
#   '"Spare18"\n',
#   '"Spare19"\n',
#   '"Spare20"\n',
#   '193\n',
#   '6,0\n',
#   '37,10\n',
#   '82,20\n',
#   '127,30\n',
#   '180,40\n'])
